# %% [markdown]
# # Fortune500 List Sorting
# This script searches the past 30 years of Fortune500 lists for the most reoccuring companies.
# It outputs a csv file to be used in the Ticker Lookup script.
#
# Script PFD:
#
# 1. FortuneList Sorting
# 2. Ticker_Lookup(in FortuneList)
# 3. Symbol_Corrections(in FortuneList)
# 4. Stock_Query
# 5. StockMarketCrash_Analytica

# %%
# import dependencies
import numpy as np
import pandas as pd

# intializing Fortune500 List lookup
start_year = 1989
end_year = 2020
year_list = list(np.arange(start_year, end_year, 1))

# creating blank dataframe to dump to
f500_df = pd.DataFrame(columns=['rank', 'company', 'year'])

# reading each fortune500 list in the year list and dumping to preliminary df
for year in year_list:
    
    # designating annual csv path
    path = f'../Resources/Fortune500_RawCSV/fortune500-{year}.csv'
    
    # reading csv into current working dataframe
    f500cw_df = pd.read_csv(path)
    
    # creating tracking column for year in current working dataframe
    f500cw_df['year'] = year
    
    # appending current working dataframe to master dataframe
    f500_df = f500_df.append(f500cw_df)
    
    f500_df.reset_index()
    

# creating sorted list of times companies appeared in the Fortune500 list
listoflists = pd.DataFrame(f500_df['company'].value_counts()).reset_index().rename(columns={'index':'company', 'company':'occurance'})

# merging sorted list back with main dataframe for company data
f500_df_sort = listoflists.merge(f500_df, on='company', how='left')

# eliminating all rows where profit was identified as NA
f500_df_sort = f500_df_sort.loc[f500_df_sort['profit ($ millions)'] != 'N.A.']

# convert profit column to float
f500_df_sort['profit ($ millions)'] = f500_df_sort['profit ($ millions)'].astype('float64')

# groupby company and taking the max values of each column
f500_df_grp = f500_df_sort.groupby('company').max().sort_values('profit ($ millions)', ascending=False)

# eliminating all occurances that fall less than 25 times in the fortune 500 lsit
f500_df_grp = f500_df_grp.loc[f500_df_grp['occurance'] >= 25]

# resetting index
f500_df_grp = f500_df_grp.reset_index()

# creating empty column(s) for ticker lookup
f500_df_grp['ticker'] = ""
f500_df_grp['company_check'] = ""

f500_df_grp
# Out:
#                    company  occurance  profit ($ millions)  rank  \
# 0              Exxon Mobil         31              45220.0     4
# 1       Berkshire Hathaway         31              44940.0   295
# 2                     AT&T         25              29450.0    56
# 3                Citigroup         25              24589.0    56
# 4                Microsoft         25              23150.0   250
# ..                     ...        ...                  ...   ...
# 159              OfficeMax         33                416.8   483
# 160  R.R. Donnelley & Sons         31                400.6   445
# 161              Tech Data         25                340.6   464
# 162       Graybar Electric         25                143.3   480
# 163          Owens & Minor         25                115.2   481
#
#      revenue ($ millions)  year ticker company_check
# 0                452926.0  2019
# 1                247837.0  2019
# 2                170756.0  2019
# 3                159229.0  2019
# 4                110360.0  2019
# ..                    ...   ...    ...           ...
# 159               13270.2  2013
# 160               11603.0  2019
# 161               37239.0  2019
# 162                7202.5  2019
# 163                9838.7  2019
#
# [164 rows x 8 columns]

# %% [markdown]
# # Symbol Search (Alpha Vantage)

# %%
# importing dependencies
import time
import pandas as pd
from config import api_key_av
import requests

# creating hard-coded values (for ease of future expansion)
max_call = 5 #calls per minute allowed by Alpha Vantage


# creating loop counters & summary stat counters
success = 0 #success API call counter
failed = 0 #failed API call counter
pull_time = 0 #future pull time variable
counter = 0 #API call counter

df_len = f500_df_grp['company'].count()

# primary loop for ticker call list to API
for index, row in f500_df_grp.iterrows():
    
    company = row['company']

    # setting API call parameters (ticker)
    params = {
        'function' : 'SYMBOL_SEARCH',
        'keywords' : company,
        'apikey' : api_key_av
    }
    
    # base API call URL
    url = 'https://www.alphavantage.co/query?'
    
    # updating time to now
    now = time.time()
    
    # API call wait function (limited to 5 calls per minute); is utilized after counter resets from 5 to 0
    if counter == 0:
        while now < pull_time:
            now = time.time()
    
    # if statement verifying proper time and counter for being able to make a successful API call
    if pull_time < now and counter < max_call:
        
        # trying API call and skipping if failed for any reason
        try:
            
            # making API call and storing data into variable
            response = requests.get(url, params).json()
            
            # THE MEAT AND POTATOS
            # extracting symbol & company name and loading to dataframe
            symbol = response['bestMatches'][0]['1. symbol']
            company_name = response['bestMatches'][0]['2. name']
            
            f500_df_grp.loc[index, 'ticker'] = symbol
            f500_df_grp.loc[index, 'company_check'] = company_name
            
            # confirming API call
            print(f'Record {index + 1} out of {df_len} processed. SUCCESS - {company} : {symbol}')
            
            success += 1
            counter += 1
            
            # resetting counter to 0 to initiate next call limit & wait function
            if counter == max_call:
                pull_time = int(time.time()) + 62
                counter = 0
                
        # handeling failed API calls
        except:
            print(f'Record {index + 1} out of {df_len} processed. FAILED - {company}')
            
            failed += 1


            
# resorting/filtering data for output
f500_df_grp = f500_df_grp[['company', 
                           'company_check', 
                           'ticker',
                           'occurance', 
                           'profit ($ millions)', 
                           'revenue ($ millions)', 
                           'year']]


# outputting to query list (for data pull)
f500_df_grp.to_csv('../Resources/Symbol_List_AV.csv', index=False)

# terminal print out of script performance
print(f'''
DONE
------------------
Query Summary
success: {success} 
failed: {failed}
total: {index + 1}
''')

# review dataframe
f500_df_grp
# Out:
# Record 1 out of 164 processed. SUCCESS - Exxon Mobil : XOM
# Record 2 out of 164 processed. SUCCESS - Berkshire Hathaway : BRK-A
# Record 3 out of 164 processed. SUCCESS - AT&T : AT
# Record 4 out of 164 processed. SUCCESS - Citigroup : C
# Record 5 out of 164 processed. SUCCESS - Microsoft : MSFT
# Record 6 out of 164 processed. FAILED - Wells Fargo
# Record 7 out of 164 processed. FAILED - General Electric
# Record 8 out of 164 processed. SUCCESS - Ford Motor : F
# Record 9 out of 164 processed. SUCCESS - Pfizer : PFE
# Record 10 out of 164 processed. SUCCESS - Intel : INTC
# Record 11 out of 164 processed. SUCCESS - Johnson & Johnson : JNJ
# Record 12 out of 164 processed. FAILED - ConocoPhillips
# Record 13 out of 164 processed. SUCCESS - Procter & Gamble : PG
# Record 14 out of 164 processed. FAILED - Altria Group
# Record 15 out of 164 processed. SUCCESS - Merck : MRK
# Record 16 out of 164 processed. SUCCESS - PepsiCo : PEP
# Record 17 out of 164 processed. SUCCESS - UnitedHealth Group : UNH
# Record 18 out of 164 processed. FAILED - Coca-Cola
# Record 19 out of 164 processed. SUCCESS - Home Depot : HD
# Record 20 out of 164 processed. SUCCESS - Union Pacific : UNP
# Record 21 out of 164 processed. SUCCESS - Bristol-Myers Squibb : BMY
# Record 22 out of 164 processed. SUCCESS - Delta Air Lines : DAL
# Record 23 out of 164 processed. FAILED - Boeing
# Record 24 out of 164 processed. SUCCESS - General Motors : GM
# Record 25 out of 164 processed. FAILED - Hewlett-Packard
# Record 26 out of 164 processed. SUCCESS - Morgan Stanley : MS
# Record 27 out of 164 processed. SUCCESS - Owens Corning : OC
# Record 28 out of 164 processed. SUCCESS - DuPont : DD
# Record 29 out of 164 processed. FAILED - Dow Chemical
# Record 30 out of 164 processed. SUCCESS - United Technologies : UTX
# Record 31 out of 164 processed. SUCCESS - U.S. Bancorp : USB
# Record 32 out of 164 processed. SUCCESS - MetLife : MET
# Record 33 out of 164 processed. SUCCESS - American Express : AXP
# Record 34 out of 164 processed. SUCCESS - Occidental Petroleum : OXY
# Record 35 out of 164 processed. SUCCESS - Time Warner : T
# Record 36 out of 164 processed. SUCCESS - Caterpillar : CAT
# Record 37 out of 164 processed. SUCCESS - Abbott Laboratories : ABT
# Record 38 out of 164 processed. SUCCESS - Texas Instruments : TXN
# Record 39 out of 164 processed. SUCCESS - CSX : CSX
# Record 40 out of 164 processed. SUCCESS - Valero Energy : VLO
# Record 41 out of 164 processed. SUCCESS - Norfolk Southern : NSC
# Record 42 out of 164 processed. SUCCESS - 3M : MMM
# Record 43 out of 164 processed. SUCCESS - Lockheed Martin : LMT
# Record 44 out of 164 processed. SUCCESS - Corning : GLW
# Record 45 out of 164 processed. SUCCESS - Marathon Oil : MRO
# Record 46 out of 164 processed. SUCCESS - McKesson : MCK
# Record 47 out of 164 processed. SUCCESS - Eli Lilly : LLY
# Record 48 out of 164 processed. FAILED - Baxter International
# Record 49 out of 164 processed. SUCCESS - FedEx : FDX
# Record 50 out of 164 processed. SUCCESS - Loews : L
# Record 51 out of 164 processed. SUCCESS - Nike : NKE
# Record 52 out of 164 processed. SUCCESS - Exelon : EXC
# Record 53 out of 164 processed. SUCCESS - Deere : DE
# Record 54 out of 164 processed. SUCCESS - Halliburton : HAL
# Record 55 out of 164 processed. SUCCESS - Southwest Airlines : LUV
# Record 56 out of 164 processed. SUCCESS - Applied Materials : AMAT
# Record 57 out of 164 processed. SUCCESS - Target : TGT
# Record 58 out of 164 processed. SUCCESS - Danaher : DHR
# Record 59 out of 164 processed. SUCCESS - General Dynamics : GD
# Record 60 out of 164 processed. SUCCESS - PPG Industries : PPG
# Record 61 out of 164 processed. SUCCESS - Northrop Grumman : NOC
# Record 62 out of 164 processed. SUCCESS - Kroger : KR
# Record 63 out of 164 processed. SUCCESS - TJX : TJX
# Record 64 out of 164 processed. SUCCESS - Duke Energy : DUK
# Record 65 out of 164 processed. SUCCESS - Tyson Foods : TSN
# Record 66 out of 164 processed. SUCCESS - CBS : CBS
# Record 67 out of 164 processed. SUCCESS - Illinois Tool Works : ITW
# Record 68 out of 164 processed. SUCCESS - Raytheon : RTN
# Record 69 out of 164 processed. SUCCESS - Sealed Air : SEE
# Record 70 out of 164 processed. SUCCESS - SunTrust Banks : STI
# Record 71 out of 164 processed. FAILED - Monsanto
# Record 72 out of 164 processed. SUCCESS - Emerson Electric : EMR
# Record 73 out of 164 processed. SUCCESS - Cigna : CI
# Record 74 out of 164 processed. SUCCESS - Progressive : PGR
# Record 75 out of 164 processed. SUCCESS - Alcoa : AA
# Record 76 out of 164 processed. SUCCESS - Marsh & McLennan : MMC
# Record 77 out of 164 processed. SUCCESS - Colgate-Palmolive : CL
# Record 78 out of 164 processed. SUCCESS - Goodyear Tire & Rubber : GT
# Record 79 out of 164 processed. SUCCESS - Southern : SO
# Record 80 out of 164 processed. SUCCESS - Humana : HUM
# Record 81 out of 164 processed. SUCCESS - Baker Hughes : BHIAX
# Record 82 out of 164 processed. SUCCESS - Viacom : VIAB
# Record 83 out of 164 processed. FAILED - Publix Super Markets
# Record 84 out of 164 processed. SUCCESS - Nucor : NUE
# Record 85 out of 164 processed. SUCCESS - Kimberly-Clark : KMB
# Record 86 out of 164 processed. SUCCESS - Archer Daniels Midland : ADM
# Record 87 out of 164 processed. SUCCESS - Textron : TXT
# Record 88 out of 164 processed. SUCCESS - Paccar : PCAR
# Record 89 out of 164 processed. SUCCESS - Williams : WMB
# Record 90 out of 164 processed. SUCCESS - International Paper : IP
# Record 91 out of 164 processed. SUCCESS - Cummins : CMI
# Record 92 out of 164 processed. SUCCESS - General Mills : GIS
# Record 93 out of 164 processed. FAILED - Nationwide
# Record 94 out of 164 processed. SUCCESS - Rite Aid : RAD
# Record 95 out of 164 processed. SUCCESS - Lincoln National : LNC
# Record 96 out of 164 processed. SUCCESS - American Electric Power : AEP
# Record 97 out of 164 processed. SUCCESS - Ashland : ASH
# Record 98 out of 164 processed. SUCCESS - Waste Management : WM
# Record 99 out of 164 processed. SUCCESS - Cardinal Health : CAH
# Record 100 out of 164 processed. SUCCESS - PPL : PPL
# Record 101 out of 164 processed. SUCCESS - First Data : FDCAX
# Record 102 out of 164 processed. FAILED - New York Life Insurance
# Record 103 out of 164 processed. FAILED - Northwestern Mutual
# Record 104 out of 164 processed. FAILED - Weyerhaeuser
# Record 105 out of 164 processed. SUCCESS - Kellogg : K
# Record 106 out of 164 processed. SUCCESS - CenterPoint Energy : CNP
# Record 107 out of 164 processed. SUCCESS - Sherwin-Williams : SHW
# Record 108 out of 164 processed. FAILED - Praxair
# Record 109 out of 164 processed. SUCCESS - Navistar International : NAV
# Record 110 out of 164 processed. SUCCESS - Gannett : GCI
# Record 111 out of 164 processed. SUCCESS - Public Service Enterprise Group : PEG
# Record 112 out of 164 processed. SUCCESS - AmerisourceBergen : ABC
# Record 113 out of 164 processed. SUCCESS - Johnson Controls : JCI
# Record 114 out of 164 processed. SUCCESS - Edison International : EIX
# Record 115 out of 164 processed. SUCCESS - Consolidated Edison : ED
# Record 116 out of 164 processed. SUCCESS - Rockwell Automation : ROK
# Record 117 out of 164 processed. SUCCESS - Best Buy : BBY
# Record 118 out of 164 processed. SUCCESS - Xerox : XRX
# Record 119 out of 164 processed. SUCCESS - Sysco : SYY
# Record 120 out of 164 processed. SUCCESS - Eastman Chemical : EMN
# Record 121 out of 164 processed. SUCCESS - Entergy : ETR
# Record 122 out of 164 processed. FAILED - Owens-Illinois
# Record 123 out of 164 processed. SUCCESS - Becton Dickinson : BDX
# Record 124 out of 164 processed. SUCCESS - Lear : LEA
# Record 125 out of 164 processed. SUCCESS - Gap : GPS
# Record 126 out of 164 processed. FAILED - Thrivent Financial for Lutherans
# Record 127 out of 164 processed. SUCCESS - VF : VFF
# Record 128 out of 164 processed. SUCCESS - Campbell Soup : CPB
# Record 129 out of 164 processed. SUCCESS - J.C. Penney : KTP
# Record 130 out of 164 processed. SUCCESS - Tenet Healthcare : THC
# Record 131 out of 164 processed. SUCCESS - DTE Energy : DTE
# Record 132 out of 164 processed. SUCCESS - Clorox : CLX
# Record 133 out of 164 processed. FAILED - McGraw-Hill
# Record 134 out of 164 processed. FAILED - H.J. Heinz
# Record 135 out of 164 processed. SUCCESS - Hormel Foods : HRL
# Record 136 out of 164 processed. SUCCESS - Dover : DOV
# Record 137 out of 164 processed. SUCCESS - ConAgra Foods : CAG
# Record 138 out of 164 processed. SUCCESS - Masco : MAS
# Record 139 out of 164 processed. SUCCESS - Mattel : MAT
# Record 140 out of 164 processed. SUCCESS - Whirlpool : WHR
# Record 141 out of 164 processed. SUCCESS - Avon Products : AVP
# Record 142 out of 164 processed. SUCCESS - Dean Foods : DF
# Record 143 out of 164 processed. SUCCESS - Genuine Parts : GPC
# Record 144 out of 164 processed. SUCCESS - W.W. Grainger : GWW
# Record 145 out of 164 processed. SUCCESS - Ryder System : R
# Record 146 out of 164 processed. FAILED - Coca-Cola Enterprises
# Record 147 out of 164 processed. SUCCESS - Nordstrom : JWN
# Record 148 out of 164 processed. SUCCESS - Arrow Electronics : ARW
# Record 149 out of 164 processed. SUCCESS - Avnet : AVT
# Record 150 out of 164 processed. SUCCESS - Foot Locker : FL
# Record 151 out of 164 processed. SUCCESS - CMS Energy : CMS
# Record 152 out of 164 processed. FAILED - Supervalu
# Record 153 out of 164 processed. SUCCESS - Pitney Bowes : PBI
# Record 154 out of 164 processed. SUCCESS - Crown Holdings : CCK
# Record 155 out of 164 processed. SUCCESS - NCR : NCR
# Record 156 out of 164 processed. SUCCESS - Office Depot : ODP
# Record 157 out of 164 processed. SUCCESS - Newell Rubbermaid : NWL
# Record 158 out of 164 processed. SUCCESS - Ball : BLDP
# Record 159 out of 164 processed. SUCCESS - Avery Dennison : AVY
# Record 160 out of 164 processed. FAILED - OfficeMax
# Record 161 out of 164 processed. SUCCESS - R.R. Donnelley & Sons : RRD
# Record 162 out of 164 processed. SUCCESS - Tech Data : TECD
# Record 163 out of 164 processed. FAILED - Graybar Electric
# Record 164 out of 164 processed. SUCCESS - Owens & Minor : OMI
#
# DONE
# ------------------
# Query Summary
# success: 140
# failed: 24
# total: 164
#                    company                  company_check ticker  occurance  \
# 0              Exxon Mobil        Exxon Mobil Corporation    XOM         31
# 1       Berkshire Hathaway        Berkshire Hathaway Inc.  BRK-A         31
# 2                     AT&T     Atlantic Power Corporation     AT         25
# 3                Citigroup                 Citigroup Inc.      C         25
# 4                Microsoft          Microsoft Corporation   MSFT         25
# ..                     ...                            ...    ...        ...
# 159              OfficeMax                                               33
# 160  R.R. Donnelley & Sons  R.R. Donnelley & Sons Company    RRD         31
# 161              Tech Data          Tech Data Corporation   TECD         25
# 162       Graybar Electric                                               25
# 163          Owens & Minor             Owens & Minor Inc.    OMI         25
#
#      profit ($ millions)  revenue ($ millions)  year
# 0                45220.0              452926.0  2019
# 1                44940.0              247837.0  2019
# 2                29450.0              170756.0  2019
# 3                24589.0              159229.0  2019
# 4                23150.0              110360.0  2019
# ..                   ...                   ...   ...
# 159                416.8               13270.2  2013
# 160                400.6               11603.0  2019
# 161                340.6               37239.0  2019
# 162                143.3                7202.5  2019
# 163                115.2                9838.7  2019
#
# [164 rows x 7 columns]

# %% [markdown]
# # Symbol Corrections
# This notebook is used to compare and update any incorrect ticker symbols found between the 2 supply methods.
#
# 1. https://www.alphavantage.co/documentation/#symbolsearch
#
# &
#
# 2. Excel Fuzzy Match (to Yahoo Finance Stock List)

# %%
# import dependencies
import numpy as np
import pandas as pd

# designating source lists (path 1 = fuzzy match data, path 2 = Alpha Vantage Symbol Search)
path = '../Resources/Symbol_List_YF.csv'
path2 = '../Resources/Symbol_List_AV.csv'

# creating Dataframes from data
df1 = pd.read_csv(path, encoding="ISO-8859-1")
df2 = pd.read_csv(path2)

# merging datasets
df2 = df2.merge(df1, on='company',how='left')

# creating dataset of un-like tickers
open_items = df2.loc[df2['ticker'] != df2['Ticker']]
open_items = open_items.reset_index(drop=True)

open_items.head()
# Out:
#    Unnamed: 0           company               company_check ticker  occurance  \
# 0           2              AT&T  Atlantic Power Corporation     AT         25
# 1           5       Wells Fargo                         NaN    NaN         25
# 2           6  General Electric                         NaN    NaN         31
# 3          11    ConocoPhillips                         NaN    NaN         31
# 4          13      Altria Group                         NaN    NaN         31
#
#    profit ($ millions)  revenue ($ millions)  year                      Name  \
# 0              29450.0              170756.0  2019                 AT&T Inc.
# 1              23057.0              101060.0  2019     Wells Fargo & Company
# 2              22208.0              183207.0  2019  General Electric Company
# 3              15550.0              237272.0  2019            ConocoPhillips
# 4              14239.0               72944.0  2019        Altria Group, Inc.
#
#   Ticker
# 0      T
# 1    WFC
# 2     GE
# 3    COP
# 4     MO

# %%
# inserting manual corrections
manual_corrections={
    'AT&T' : 'T',
    'Morgan Stanley' : 'MS',
    'DuPont' : 'DD',
    'Time Warner' : 'TWX',
    'Baker Hughes' : 'BHI',
    'First Data' : 'FDC',
    'J.C. Penney' : 'JCP',
    'Ball' : 'BLL',
    'OfficeMax' : 'OMX'}

# %%
# updating open items to form corrections list
for index, item in open_items.iterrows():
    if open_items.loc[index, 'company'] in list(manual_corrections.keys()):
        company = open_items.loc[index, 'company']
        open_items.loc[index, 'ticker'] = manual_corrections[company]
    if pd.isna(open_items.loc[index, 'ticker']):
        open_items.loc[index, 'ticker'] = open_items.loc[index, 'Ticker']

# creating corrections list from corrected open items
corrections = open_items[['company', 'ticker', 'occurance', 'profit ($ millions)', 'revenue ($ millions)', 'year']]

correction_count = len(corrections['company'])

print(f'''
Correction List Successful
Total Items: {correction_count}
''')

# cleaning df2 into a final df to export
query_list = df2[['company', 'ticker', 'occurance', 'profit ($ millions)', 'revenue ($ millions)', 'year']]


# changing out corrections on main dataframe

total_count = 0
for index, company in df2.iterrows():
    if query_list.loc[index, 'company'] in list(corrections['company']):
        company = query_list.loc[index, 'company']
        query_list.loc[index, 'ticker'] = corrections.loc[corrections['company'] == company]['ticker'].item()
        total_count += 1
print(f'''
----------
Confirmed Corrections Made: {total_count} of {correction_count}
''')

# Output list as final ticker query list
save_path = '../Resources/Query_List.csv'
query_list.to_csv(save_path)

print(f'''
----------
Query_list.csv save successful at:{save_path}
Returning Query List..
''')

query_list
# Out:
# Correction List Successful
# Total Items: 35
#
#
# ----------
# Confirmed Corrections Made: 35 of 35
#
#
# ----------
# Query_list.csv save successful at:../Resources/Query_List.csv
# Returning Query List..
# C:\Users\armck\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:29: FutureWarning: `item` has been deprecated and will be removed in a future version
#                    company ticker  occurance  profit ($ millions)  \
# 0              Exxon Mobil    XOM         31              45220.0
# 1       Berkshire Hathaway  BRK-A         31              44940.0
# 2                     AT&T      T         25              29450.0
# 3                Citigroup      C         25              24589.0
# 4                Microsoft   MSFT         25              23150.0
# ..                     ...    ...        ...                  ...
# 159              OfficeMax    OMX         33                416.8
# 160  R.R. Donnelley & Sons    RRD         31                400.6
# 161              Tech Data   TECD         25                340.6
# 162       Graybar Electric    NaN         25                143.3
# 163          Owens & Minor    OMI         25                115.2
#
#      revenue ($ millions)  year
# 0                452926.0  2019
# 1                247837.0  2019
# 2                170756.0  2019
# 3                159229.0  2019
# 4                110360.0  2019
# ..                    ...   ...
# 159               13270.2  2013
# 160               11603.0  2019
# 161               37239.0  2019
# 162                7202.5  2019
# 163                9838.7  2019
#
# [164 rows x 6 columns]
